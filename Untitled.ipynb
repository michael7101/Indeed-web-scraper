# %%
import csv
from datetime import datetime, timedelta
import requests
from bs4 import BeautifulSoup, SoupStrainer
import httplib2
import re
import pandas as pd
import math
import time
from time import sleep
from random import randint

# %%
baselink = "https://ca.indeed.com"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.51 Safari/537.36"}

# %%
df = pd.DataFrame(columns=['Title', 'Company', 'Location', 'JobLink',
                           'CompanyLink', 'DatePosted', 'ExtractDate',
                           'Description', 'Salary', 'JobType', 'Remote', 'Reviews', 'Stars'])

# %%
# Generate url from position, location and date posted.
def get_url(position, location, dateposted):
    template = 'https://ca.indeed.com/jobs?q={}&l={}&fromage={}'
    position = position.replace(' ', '+')
    location = location.replace(' ', '+')
    dateposted = dateposted.replace(' ', '+')
    url = template.format(position, location, dateposted)
    return url
url = get_url('data analyst', 'canada', '7')
print(url)
# Out:
# https://ca.indeed.com/jobs?q=data+analyst&l=canada&fromage=7

# %%
r = requests.get(url, headers = headers)

# %%
soup = BeautifulSoup(r.content, 'html.parser').prettify()

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <title>
#    Just a moment...
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="noindex,nofollow" name="robots"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <link href="/cdn-cgi/styles/challenges.css" rel="stylesheet"/>
#  </head>
#  <body class="no-js">
#   <div class="main-wrapper" role="main">
#    <div class="main-content">
#     <h1 class="zone-name-title h1">
#      <img class="heading-favicon" onerror="this.onerror=null;this.parentNode.removeChild(this)" src="/favicon.ico"/>
#      ca.indeed.com
#     </h1>
#     <h2 class="h2" id="challenge-running">
#      Checking if the site connection is secure
#     </h2>
#     <noscript>
#      <div id="challenge-error-title">
#       <div class="h2">
#        <span class="icon-wrapper">
#         <div class="heading-icon warning-icon">
#         </div>
#        </span>
#        <span id="challenge-error-text">
#         Enable JavaScript and cookies to continue
#        </span>
#       </div>
#      </div>
#     </noscript>
#     <div id="trk_jschal_js" style="display:none;background-image:url('/cdn-cgi/images/trace/managed/nojs/transparent.gif?ray=751fdc3bda3bc38a')">
#     </div>
#     <div class="core-msg spacer" id="challenge-body-text">
#      ca.indeed.com needs to review the security of your connection before proceeding.
#     </div>
#     <form action="/jobs?q=data+analyst&amp;l=canada&amp;fromage=7&amp;__cf_chl_f_tk=piK63Vta3QXGnnbTes_enBmaHwijtqafSYB6B7wwNMc-1664403562-0-gaNycGzNB70" enctype="application/x-www-form-urlencoded" id="challenge-form" method="POST">
#      <input name="md" type="hidden" value="Ln8f.8oj_JHKMvMQfZZZznFOIKFULIzXPGibZnuGkD4-1664403562-0-ASwEuu5iYZfIPq30l052vV6F3gKkDk4tZRhKsAHOsuOUGsz42XtHw_BTN4qC4mxoskRKQsI8-icyFA_sdFMrzg347nFkndQtQ1xHKfHAvdDBqdBsRHl2RJTqTRvOCMCvm7zlxLN28L8CMj1-PgCNUIldm37rGN6Oa6AJHYRTS3mMB7-Z0cuLOJxL2WsErTzkZCLAngpIX4CwgNUSon1rPcmN-_kUUOeDRQUDKRmKpX3nsmyDIPzSeNEZfU2yFJ1RqG3WR19jZwyzOrUU7YtUWtE8c2HYAMsbix22yDw9ycoEpY3DQylJTmlguMhTy0mwSIFUz1tm72-POvHpG00ejvqmKJpllVqELZCCHj8YbXCYvy7WTjzAKEz2rx0z7q7BFthwbVXcdlbzlCoCXfOL2DY9FdJ_Pwff2Yfyu7gWmc02K7UDO3xqKq46k5cmRD-Y8eJFTtayuNWZ3_y1KCxQ_MZ4jn0bD2M6Wa8jgsB7wnazTvztPy2TVYjO_ZR64yHihrdW6skQzQ4KsR7knnZQ0CSvsoWXngIBdtfB0ARJdF3FBNa6VnB_nFZItP8JfhyKyL5Khv8Jot9chz-mJyb9d-3yRQ5YsSbxwkotI3d-rbo9t6yWYZOfbyLBbfsUQ_1d0_FsKGl49Ka71sa6RsMGNIWA5tw4vFXDBHZZImwy_n51gzKo_tNbjA12NUP_F6A031k7LhS9m0qWJU26XOGDVW_DKMuO4EmL0Mk8Tfof5JHX"/>
#      <input name="r" type="hidden" value="9bHHe2l9jtowu5nq6OMGYaJH9uHX1369t76sTsgs8a0-1664403562-0-..."/>
#     </form>
#    </div>
#   </div>
#   <script>
#    (function(){
#         window._cf_chl_opt={
#             cvId: '2',
#             cType: 'managed',
#             cNounce: '14012',
#             cRay: '751fdc3bda3bc38a',
#             cHash: 'd7d2c8bbe57313d',
#             cUPMDTk: "\/jobs?q=data+analyst&l=canada&fromage=7&__cf_chl_tk=piK63Vta3QXGnnbTes_enBmaHwijtqafSYB6B7wwNMc-1664403562-0-gaNycGzNB70",
#             cFPWv: 'b',
#             cTTimeMs: '1000',
#             cTplV: 4,
#             cTplB: 'cf',
#             cRq: {
#                 ru: 'aHR0cHM6Ly9jYS5pbmRlZWQuY29tL2pvYnM/cT1kYXRhK2FuYWx5c3QmbD1jYW5hZGEmZnJvbWFnZT03',
#                 ra: 'TW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzk5LjAuNDg0NC41MSBTYWZhcmkvNTM3LjM2',
#                 rm: 'R0VU',
#                 d: '...',
#                 t: 'MTY2NDQwMzU2Mi44NjgwMDA=',
#                 m: 'w/CYfaO9Q0DNzGTrtCENP3k731+EU2ApKrEhyoeuB4o=',
#                 i1: 'iUYpMIwYk1Mmu3oXWIZlBg==',
#                 i2: 'kGfi9ODDIiSM6zBQ4lswxQ==',
#                 zh: '2kfjrLYfAVNem19Lin3oP+VKo7ladb55se1eVtiLLnQ=',
#                 uh: 'dGqjwVEXnjmVLxK2OBRA5xDPkd+wD+AQB8AizS0vr1w=',
#                 hh: 'VKEgNEB6ybA0rVgkEIg5nvdIvYV8q3qk+zcdMKWdrG0=',
#             }
#         };
#         var trkjs = document.createElement('img');
#         trkjs.setAttribute('src', '/cdn-cgi/images/trace/managed/js/transparent.gif?ray=751fdc3bda3bc38a');
#         trkjs.setAttribute('style', 'display: none');
#         document.body.appendChild(trkjs);
#         var cpo = document.createElement('script');
#         cpo.src = '/cdn-cgi/challenge-platform/h/b/orchestrate/managed/v1?ray=751fdc3bda3bc38a';
#         window._cf_chl_opt.cOgUHash = location.hash === '' && location.href.indexOf('#') !== -1 ? '#' : location.hash;
#         window._cf_chl_opt.cOgUQuery = location.search === '' && location.href.slice(0, -window._cf_chl_opt.cOgUHash.length).indexOf('?') !== -1 ? '?' : location.search;
#         if (window.history && window.history.replaceState) {
#             var ogU = location.pathname + window._cf_chl_opt.cOgUQuery + window._cf_chl_opt.cOgUHash;
#             history.replaceState(null, null, "\/jobs?q=data+analyst&l=canada&fromage=7&__cf_chl_rt_tk=piK63Vta3QXGnnbTes_enBmaHwijtqafSYB6B7wwNMc-1664403562-0-gaNycGzNB70" + window._cf_chl_opt.cOgUHash);
#             cpo.onload = function() {
#                 history.replaceState(null, null, ogU);
#             };
#         }
#         document.getElementsByTagName('head')[0].appendChild(cpo);
#     }());
#   </script>
#   <div class="footer" role="contentinfo">
#    <div class="footer-inner">
#     <div class="clearfix diagnostic-wrapper">
#      <div class="ray-id">
#       Ray ID:
#       <code>
#        751fdc3bda3bc38a
#       </code>
#      </div>
#     </div>
#     <div class="text-center">
#      Performance &amp; security by
#      <a href="https://www.cloudflare.com?utm_source=challenge&amp;utm_campaign=m" rel="noopener noreferrer" target="_blank">
#       Cloudflare
#      </a>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <title>
#    Just a moment...
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="noindex,nofollow" name="robots"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <link href="/cdn-cgi/styles/challenges.css" rel="stylesheet"/>
#  </head>
#  <body class="no-js">
#   <div class="main-wrapper" role="main">
#    <div class="main-content">
#     <h1 class="zone-name-title h1">
#      <img class="heading-favicon" onerror="this.onerror=null;this.parentNode.removeChild(this)" src="/favicon.ico"/>
#      ca.indeed.com
#     </h1>
#     <h2 class="h2" id="challenge-running">
#      Checking if the site connection is secure
#     </h2>
#     <noscript>
#      <div id="challenge-error-title">
#       <div class="h2">
#        <span class="icon-wrapper">
#         <div class="heading-icon warning-icon">
#         </div>
#        </span>
#        <span id="challenge-error-text">
#         Enable JavaScript and cookies to continue
#        </span>
#       </div>
#      </div>
#     </noscript>
#     <div id="trk_jschal_js" style="display:none;background-image:url('/cdn-cgi/images/trace/managed/nojs/transparent.gif?ray=751fdc3bda3bc38a')">
#     </div>
#     <div class="core-msg spacer" id="challenge-body-text">
#      ca.indeed.com needs to review the security of your connection before proceeding.
#     </div>
#     <form action="/jobs?q=data+analyst&amp;l=canada&amp;fromage=7&amp;__cf_chl_f_tk=piK63Vta3QXGnnbTes_enBmaHwijtqafSYB6B7wwNMc-1664403562-0-gaNycGzNB70" enctype="application/x-www-form-urlencoded" id="challenge-form" method="POST">
#      <input name="md" type="hidden" value="Ln8f.8oj_JHKMvMQfZZZznFOIKFULIzXPGibZnuGkD4-1664403562-0-ASwEuu5iYZfIPq30l052vV6F3gKkDk4tZRhKsAHOsuOUGsz42XtHw_BTN4qC4mxoskRKQsI8-icyFA_sdFMrzg347nFkndQtQ1xHKfHAvdDBqdBsRHl2RJTqTRvOCMCvm7zlxLN28L8CMj1-PgCNUIldm37rGN6Oa6AJHYRTS3mMB7-Z0cuLOJxL2WsErTzkZCLAngpIX4CwgNUSon1rPcmN-_kUUOeDRQUDKRmKpX3nsmyDIPzSeNEZfU2yFJ1RqG3WR19jZwyzOrUU7YtUWtE8c2HYAMsbix22yDw9ycoEpY3DQylJTmlguMhTy0mwSIFUz1tm72-POvHpG00ejvqmKJpllVqELZCCHj8YbXCYvy7WTjzAKEz2rx0z7q7BFthwbVXcdlbzlCoCXfOL2DY9FdJ_Pwff2Yfyu7gWmc02K7UDO3xqKq46k5cmRD-Y8eJFTtayuNWZ3_y1KCxQ_MZ4jn0bD2M6Wa8jgsB7wnazTvztPy2TVYjO_ZR64yHihrdW6skQzQ4KsR7knnZQ0CSvsoWXngIBdtfB0ARJdF3FBNa6VnB_nFZItP8JfhyKyL5Khv8Jot9chz-mJyb9d-3yRQ5YsSbxwkotI3d-rbo9t6yWYZOfbyLBbfsUQ_1d0_FsKGl49Ka71sa6RsMGNIWA5tw4vFXDBHZZImwy_n51gzKo_tNbjA12NUP_F6A031k7LhS9m0qWJU26XOGDVW_DKMuO4EmL0Mk8Tfof5JHX"/>
#      <input name="r" type="hidden" value="9bHHe2l9jtowu5nq6OMGYaJH9uHX1369t76sTsgs8a0-1664403562-0-..."/>
#     </form>
#    </div>
#   </div>
#   <script>
#    (function(){
#         window._cf_chl_opt={
#             cvId: '2',
#             cType: 'managed',
#             cNounce: '14012',
#             cRay: '751fdc3bda3bc38a',
#             cHash: 'd7d2c8bbe57313d',
#             cUPMDTk: "\/jobs?q=data+analyst&l=canada&fromage=7&__cf_chl_tk=piK63Vta3QXGnnbTes_enBmaHwijtqafSYB6B7wwNMc-1664403562-0-gaNycGzNB70",
#             cFPWv: 'b',
#             cTTimeMs: '1000',
#             cTplV: 4,
#             cTplB: 'cf',
#             cRq: {
#                 ru: 'aHR0cHM6Ly9jYS5pbmRlZWQuY29tL2pvYnM/cT1kYXRhK2FuYWx5c3QmbD1jYW5hZGEmZnJvbWFnZT03',
#                 ra: 'TW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzk5LjAuNDg0NC41MSBTYWZhcmkvNTM3LjM2',
#                 rm: 'R0VU',
#                 d: '...',
#                 t: 'MTY2NDQwMzU2Mi44NjgwMDA=',
#                 m: 'w/CYfaO9Q0DNzGTrtCENP3k731+EU2ApKrEhyoeuB4o=',
#                 i1: 'iUYpMIwYk1Mmu3oXWIZlBg==',
#                 i2: 'kGfi9ODDIiSM6zBQ4lswxQ==',
#                 zh: '2kfjrLYfAVNem19Lin3oP+VKo7ladb55se1eVtiLLnQ=',
#                 uh: 'dGqjwVEXnjmVLxK2OBRA5xDPkd+wD+AQB8AizS0vr1w=',
#                 hh: 'VKEgNEB6ybA0rVgkEIg5nvdIvYV8q3qk+zcdMKWdrG0=',
#             }
#         };
#         var trkjs = document.createElement('img');
#         trkjs.setAttribute('src', '/cdn-cgi/images/trace/managed/js/transparent.gif?ray=751fdc3bda3bc38a');
#         trkjs.setAttribute('style', 'display: none');
#         document.body.appendChild(trkjs);
#         var cpo = document.createElement('script');
#         cpo.src = '/cdn-cgi/challenge-platform/h/b/orchestrate/managed/v1?ray=751fdc3bda3bc38a';
#         window._cf_chl_opt.cOgUHash = location.hash === '' && location.href.indexOf('#') !== -1 ? '#' : location.hash;
#         window._cf_chl_opt.cOgUQuery = location.search === '' && location.href.slice(0, -window._cf_chl_opt.cOgUHash.length).indexOf('?') !== -1 ? '?' : location.search;
#         if (window.history && window.history.replaceState) {
#             var ogU = location.pathname + window._cf_chl_opt.cOgUQuery + window._cf_chl_opt.cOgUHash;
#             history.replaceState(null, null, "\/jobs?q=data+analyst&l=canada&fromage=7&__cf_chl_rt_tk=piK63Vta3QXGnnbTes_enBmaHwijtqafSYB6B7wwNMc-1664403562-0-gaNycGzNB70" + window._cf_chl_opt.cOgUHash);
#             cpo.onload = function() {
#                 history.replaceState(null, null, ogU);
#             };
#         }
#         document.getElementsByTagName('head')[0].appendChild(cpo);
#     }());
#   </script>
#   <div class="footer" role="contentinfo">
#    <div class="footer-inner">
#     <div class="clearfix diagnostic-wrapper">
#      <div class="ray-id">
#       Ray ID:
#       <code>
#        751fdc3bda3bc38a
#       </code>
#      </div>
#     </div>
#     <div class="text-center">
#      Performance &amp; security by
#      <a href="https://www.cloudflare.com?utm_source=challenge&amp;utm_campaign=m" rel="noopener noreferrer" target="_blank">
#       Cloudflare
#      </a>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>
